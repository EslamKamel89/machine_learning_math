# %%
from utils import pr , measure_time
import numpy as np

# %%
v = np.array([3.0 , 4.0])
pr(np.linalg.norm(v))
# Out:
# +++++++++++++++++++++++++++++++++++
# <class 'numpy.float64'>
# np.float64(5.0)
# -----

# %%
v = np.array([3.0, 4.0])
u = np.array([1.0, 1.0])
pr(np.linalg.norm(v-u) , 'the right way to calculate the distance')
pr(np.linalg.norm(v)-np.linalg.norm(u) , 'the wrong way calculate the distance')
# Out:
# +++++++++++++++++ the right way to calculate the distance ++++++++++++++++++
# <class 'numpy.float64'>
# np.float64(3.605551275463989)
# -----
#
# +++++++++++++++++ the wrong way calculate the distance ++++++++++++++++++
# <class 'numpy.float64'>
# np.float64(3.585786437626905)
# -----
