# %%
from utils import pr , measure_time
import numpy as np

# %%
v = np.array([1,2,3])
pr(np.linalg.norm(v))
# Out:
# +++++++++++++++++++++++++++++++++++
# <class 'numpy.float64'>
# 3.7416573867739413
# -----
# np.float64(3.7416573867739413)
