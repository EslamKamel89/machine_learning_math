# %%
from utils import pr , measure_time
import numpy as np

# %%
N = np.array([1,2,3])
M = np.array([
    [1,2,3],
    [4,5,6]
])
pr(N,'N')
pr(N.shape,'N.shape')
pr(M,'M')
pr(M.shape,'M.shape')
# Out:
# +++++++++++++++++ N ++++++++++++++++++
# <class 'numpy.ndarray'>
# [1 2 3]
# -----
#
# +++++++++++++++++ N.shape ++++++++++++++++++
# <class 'tuple'>
# (3,)
# -----
#
# +++++++++++++++++ M ++++++++++++++++++
# <class 'numpy.ndarray'>
# [[1 2 3]
#  [4 5 6]]
# -----
#
# +++++++++++++++++ M.shape ++++++++++++++++++
# <class 'tuple'>
# (2, 3)
# -----
# (2, 3)
