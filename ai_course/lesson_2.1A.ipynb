# %%
from utils import pr , measure_time
import numpy as np

# %%
V = np.array([3,5])
B = np.array([[1, -1],
              [1,  1]])
C = np.linalg.solve(B ,V)
pr(C)
# Out:
# +++++++++++++++++++++++++++++++++++
# <class 'numpy.ndarray'>
# array([4., 1.])
# -----
