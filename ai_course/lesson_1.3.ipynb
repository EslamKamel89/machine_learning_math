# %%
from utils import pr , measure_time
import numpy as np

# %%
v = np.array([1.0, 2.0, 3.0])
u = np.array([4.0, -1.0, 2.0])
pr(v , 'v')
pr(u , 'u')
pr(np.dot(u,v) , 'np.dot(u,v)')
# Out:
# +++++++++++++++++ v ++++++++++++++++++
# <class 'numpy.ndarray'>
# array([1., 2., 3.])
# -----
#
# +++++++++++++++++ u ++++++++++++++++++
# <class 'numpy.ndarray'>
# array([ 4., -1.,  2.])
# -----
#
# +++++++++++++++++ np.dot(u,v) ++++++++++++++++++
# <class 'numpy.float64'>
# np.float64(8.0)
# -----
