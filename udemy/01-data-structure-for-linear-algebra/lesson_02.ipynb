# %%
from utils import pr
import numpy as np

# %% [markdown]
# Let's build a tiny linear model.
# In the dataset below Each row represents a house.
# ```
# [bedrooms, distance_to_school]
# ```
# Shape:
# ```
# (3, 2)
# ```

# %%
X = np.array([
    [3, 2],
    [4, 1],
    [2, 5]
])

# %% [markdown]
# Define parameters

# %%
w = np.array([50000, -10000])

# %%
predictions = X @ w

# %%
pr(predictions)
# Out:
# +++++++++++++++++++++++++++++++++++
# <class 'numpy.ndarray'>
# array([130000, 190000,  50000])
# -----
